# %%
import pandas as pd

# %%
df  = pd.read_csv("Student Depression Dataset.csv")

# %%
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
# ...

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
#display the last five record of dataset
df.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# ...

# %%
#display the number of rows and columns 
df.shape
# Out:
# (27901, 18)

# %%
#display summary or info about datasets including datatypes and non null counts 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
#get descriptive statistics for numerical columns in datasets
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
#select the age column from dataset
df["Age"]
# Out:
# 0        33.0
# 1        24.0
# 2        31.0
# 3        28.0
# 4        25.0
#          ...
# 27896    27.0
# 27897    27.0
# 27898    31.0
# 27899    18.0
# 27900    27.0
# Name: Age, Length: 27901, dtype: float64

# %%
#select the age column from dataset
df["Age","id"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Age', 'id')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 #select the age column from dataset
# ----> 2 df["Age","id"]
#
# ...

# %%
df["Age"],["id"]
# Out:
# (0        33.0
#  1        24.0
#  2        31.0
#  3        28.0
#  4        25.0
#           ...
#  27896    27.0
#  27897    27.0
#  27898    31.0
#  27899    18.0
#  27900    27.0
#  Name: Age, Length: 27901, dtype: float64,
#  ['id'])

# %%
df["Age"],["CGPA"]
# Out:
# (0        33.0
#  1        24.0
#  2        31.0
#  3        28.0
#  4        25.0
#           ...
#  27896    27.0
#  27897    27.0
#  27898    31.0
#  27899    18.0
#  27900    27.0
#  Name: Age, Length: 27901, dtype: float64,
#  ['CGPA'])

# %%
df[["Age","CGPA"]]
# Out:
#         Age  CGPA
# 0      33.0  8.97
# 1      24.0  5.90
# 2      31.0  7.03
# 3      28.0  5.59
# 4      25.0  8.13
# ...     ...   ...
# 27896  27.0  5.75
# 27897  27.0  9.40
# 27898  31.0  6.61
# 27899  18.0  6.88
# 27900  27.0  9.24
#
# [27901 rows x 2 columns]

# %%
#SELECT THE FIRST ROW FROM THE DATASETS BY INDEX 
df.iloc[0]
# Out:
# id                                                   2
# Gender                                            Male
# Age                                               33.0
# City                                     Visakhapatnam
# Profession                                     Student
# Academic Pressure                                  5.0
# Work Pressure                                      0.0
# CGPA                                              8.97
# Study Satisfaction                                 2.0
# Job Satisfaction                                   0.0
# Sleep Duration                               5-6 hours
# Dietary Habits                                 Healthy
# Degree                                         B.Pharm
# Have you ever had suicidal thoughts ?              Yes
# Work/Study Hours                                   3.0
# Financial Stress                                   1.0
# Family History of Mental Illness                    No
# ...

# %%
#select the row with label index 0 from dataset
df.loc[0]
# Out:
# id                                                   2
# Gender                                            Male
# Age                                               33.0
# City                                     Visakhapatnam
# Profession                                     Student
# Academic Pressure                                  5.0
# Work Pressure                                      0.0
# CGPA                                              8.97
# Study Satisfaction                                 2.0
# Job Satisfaction                                   0.0
# Sleep Duration                               5-6 hours
# Dietary Habits                                 Healthy
# Degree                                         B.Pharm
# Have you ever had suicidal thoughts ?              Yes
# Work/Study Hours                                   3.0
# Financial Stress                                   1.0
# Family History of Mental Illness                    No
# ...

# %%
df.loc[3]
# Out:
# id                                              30
# Gender                                      Female
# Age                                           28.0
# City                                      Varanasi
# Profession                                 Student
# Academic Pressure                              3.0
# Work Pressure                                  0.0
# CGPA                                          5.59
# Study Satisfaction                             2.0
# Job Satisfaction                               0.0
# Sleep Duration                           7-8 hours
# Dietary Habits                            Moderate
# Degree                                         BCA
# Have you ever had suicidal thoughts ?          Yes
# Work/Study Hours                               4.0
# Financial Stress                               5.0
# Family History of Mental Illness               Yes
# Depression                                       1
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# id                                              30
# Gender                                      Female
# Age                                           28.0
# City                                      Varanasi
# Profession                                 Student
# Academic Pressure                              3.0
# Work Pressure                                  0.0
# CGPA                                          5.59
# Study Satisfaction                             2.0
# Job Satisfaction                               0.0
# Sleep Duration                           7-8 hours
# Dietary Habits                            Moderate
# Degree                                         BCA
# Have you ever had suicidal thoughts ?          Yes
# Work/Study Hours                               4.0
# Financial Stress                               5.0
# Family History of Mental Illness               Yes
# Depression                                       1
# Name: 3, dtype: object

# %%
#select rows from 1 to 5 and column from 2 to 5
df.iloc[1:5,2:5]
# Out:
#     Age       City Profession
# 1  24.0  Bangalore    Student
# 2  31.0   Srinagar    Student
# 3  28.0   Varanasi    Student
# 4  25.0     Jaipur    Student

# %%
df.loc[1:5,2:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.loc[1:5,2:5]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1020, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
df.loc[[1:5,2:5]]

# %%
#FILTERING THE DATASETS FOR ROWS WHERE AGE IS GREATER THAN 40 
df[df["Age"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 #FILTERING THE DATASETS FOR ROWS WHERE AGE IS GREATER THAN 40
# ----> 2 df[df["Age"]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
df[df["Age"]>40]
# Out:
#            id  Gender   Age         City Profession  Academic Pressure  \
# 1076     5569  Female  42.0       Rajkot    Student                2.0
# 2909    14768  Female  58.0      Chennai    Student                4.0
# 3436    17213    Male  49.0       Nagpur    Student                3.0
# 4386    22004  Female  51.0       Bhopal    Student                2.0
# 5537    27918  Female  44.0     Srinagar    Student                1.0
# 6662    33392    Male  43.0       Rajkot    Student                5.0
# 9006    45393    Male  46.0       Nashik    Student                1.0
# 9238    46602    Male  59.0       Nashik    Student                1.0
# 11532   58262    Male  42.0      Kolkata    Student                5.0
# 13499   68441    Male  54.0         Agra    Student                5.0
# 13618   69032  Female  48.0    Ghaziabad    Student                3.0
# 14819   74887  Female  56.0     Ludhiana    Student                3.0
# ...

# %%
#use a query method to filter rows where age is greater than 40
df.query("Age > 40")
# Out:
#            id  Gender   Age         City Profession  Academic Pressure  \
# 1076     5569  Female  42.0       Rajkot    Student                2.0
# 2909    14768  Female  58.0      Chennai    Student                4.0
# 3436    17213    Male  49.0       Nagpur    Student                3.0
# 4386    22004  Female  51.0       Bhopal    Student                2.0
# 5537    27918  Female  44.0     Srinagar    Student                1.0
# 6662    33392    Male  43.0       Rajkot    Student                5.0
# 9006    45393    Male  46.0       Nashik    Student                1.0
# 9238    46602    Male  59.0       Nashik    Student                1.0
# 11532   58262    Male  42.0      Kolkata    Student                5.0
# 13499   68441    Male  54.0         Agra    Student                5.0
# 13618   69032  Female  48.0    Ghaziabad    Student                3.0
# 14819   74887  Female  56.0     Ludhiana    Student                3.0
# ...

# %%
#check if there are any missing values in dataframes

# %%
#check if there are any missing values in dataframes
df.isnull()
# Out:
#           id  Gender    Age   City  Profession  Academic Pressure  \
# 0      False   False  False  False       False              False
# 1      False   False  False  False       False              False
# 2      False   False  False  False       False              False
# 3      False   False  False  False       False              False
# 4      False   False  False  False       False              False
# ...      ...     ...    ...    ...         ...                ...
# 27896  False   False  False  False       False              False
# 27897  False   False  False  False       False              False
# 27898  False   False  False  False       False              False
# 27899  False   False  False  False       False              False
# 27900  False   False  False  False       False              False
#
#        Work Pressure   CGPA  Study Satisfaction  Job Satisfaction  \
# 0              False  False               False             False
# ...

# %%
#count the number of missing values of in the column
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df.fillna(0)
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.fillna(0)
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...
