# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ipl= pd.read_csv('matches.csv')

# %%
ipl
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
ipl.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl.tail()
# Out:
#         id  season           city        date                  team1  \
# 751  11347    2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415    2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
ipl.shape
# Out:
# (756, 18)

# %%
ipl.shape[1]
# Out:
# 18

# %%
ipl.shape[0]
# Out:
# 756

# %%
ipl.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
ipl.index
# Out:
# RangeIndex(start=0, stop=756, step=1)

# %%
ipl.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
ipl.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
ipl.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 751  False   False  False  False  False  False        False          False
# 752  False   False  False  False  False  False        False          False
# 753  False   False  False  False  False  False        False          False
# 754  False   False  False  False  False  False        False          False
# 755  False   False  False  False  False  False        False          False
#
# ...

# %%
ipl.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
ipl.loc[[0,5],"toss_winner"]
# Out:
# 0    Royal Challengers Bangalore
# 5            Sunrisers Hyderabad
# Name: toss_winner, dtype: object

# %%
ipl[ipl['toss_winner'] == "Mumbai Indians"]
# Out:
#         id  season       city        date                        team1  \
# 6        7    2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 9       10    2017     Mumbai  12-04-2017          Sunrisers Hyderabad
# 11      12    2017  Bangalore  14-04-2017  Royal Challengers Bangalore
# 15      16    2017     Mumbai  16-04-2017                Gujarat Lions
# 21      22    2017     Indore  20-04-2017              Kings XI Punjab
# ..     ...     ...        ...         ...                          ...
# 729  11325    2019      Delhi  18-04-2019               Mumbai Indians
# 742  11338    2019    Kolkata  28-04-2019        Kolkata Knight Riders
# 746  11342    2019     Mumbai  02-05-2019               Mumbai Indians
# 751  11347    2019     Mumbai  05-05-2019        Kolkata Knight Riders
# 755  11415    2019  Hyderabad  12-05-2019               Mumbai Indians
#
#                    team2     toss_winner toss_decision  result  dl_applied  \
# ...

# %%
ipl['season'].nunique()
# Out:
# 12

# %%
ipl['season'].unique()
# Out:
# array([2017, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018,
#        2019], dtype=int64)

# %%
ipl.loc[2:20:2,["city","date","team1","team2"]]
# Out:
#          city        date                        team1  \
# 2      Rajkot  07-04-2017                Gujarat Lions
# 4   Bangalore  08-04-2017  Royal Challengers Bangalore
# 6      Mumbai  09-04-2017        Kolkata Knight Riders
# 8        Pune  11-04-2017             Delhi Daredevils
# 10    Kolkata  13-04-2017              Kings XI Punjab
# 12     Rajkot  14-04-2017       Rising Pune Supergiant
# 14      Delhi  15-04-2017             Delhi Daredevils
# 16  Bangalore  16-04-2017       Rising Pune Supergiant
# 18  Hyderabad  17-04-2017          Sunrisers Hyderabad
# 20  Hyderabad  19-04-2017          Sunrisers Hyderabad
#
#                           team2
# 2         Kolkata Knight Riders
# 4              Delhi Daredevils
# 6                Mumbai Indians
# 8        Rising Pune Supergiant
# 10        Kolkata Knight Riders
# 12                Gujarat Lions
# 14              Kings XI Punjab
# 16  Royal Challengers Bangalore
# 18              Kings XI Punjab
# ...

# %%
ipl[ipl['season']==2011]
# Out:
#       id  season       city        date                        team1  \
# 234  235    2011    Chennai  08-04-2011          Chennai Super Kings
# 235  236    2011  Hyderabad  09-04-2011              Deccan Chargers
# 236  237    2011      Kochi  09-04-2011         Kochi Tuskers Kerala
# 237  238    2011      Delhi  10-04-2011             Delhi Daredevils
# 238  239    2011     Mumbai  10-04-2011              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 302  303    2011    Kolkata  22-05-2011        Kolkata Knight Riders
# 303  304    2011     Mumbai  24-05-2011  Royal Challengers Bangalore
# 304  305    2011     Mumbai  25-05-2011        Kolkata Knight Riders
# 305  306    2011    Chennai  27-05-2011  Royal Challengers Bangalore
# 306  307    2011    Chennai  28-05-2011          Chennai Super Kings
#
#                            team2           toss_winner toss_decision  result  \
# ...

# %%
ipl['team1'].value_counts()
# Out:
# team1
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Delhi Capitals                   6
# Name: count, dtype: int64

# %%
ipl['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
ipl['winner'].value_counts().head(10)
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Name: count, dtype: int64

# %%
ipl[ipl['toss_winner']==ipl['winner']].shape[0]
# Out:
# 393

# %%
ipl['toss_decision'].value_counts()
# Out:
# toss_decision
# field    463
# bat      293
# Name: count, dtype: int64

# %%
ipl.groupby('toss_decision')['winner'].count()
# Out:
# toss_decision
# bat      292
# field    460
# Name: winner, dtype: int64

# %%
ipl['venue'].value_counts().head(10)
# Out:
# venue
# Eden Gardens                                  77
# M Chinnaswamy Stadium                         73
# Wankhede Stadium                              73
# Feroz Shah Kotla                              67
# Rajiv Gandhi International Stadium, Uppal     56
# MA Chidambaram Stadium, Chepauk               49
# Sawai Mansingh Stadium                        47
# Punjab Cricket Association Stadium, Mohali    35
# Maharashtra Cricket Association Stadium       21
# Subrata Roy Sahara Stadium                    17
# Name: count, dtype: int64

# %%
ipl[ipl['win_by_runs']==ipl['win_by_runs'].max()]
# Out:
#     id  season   city        date           team1             team2  \
# 43  44    2017  Delhi  06-05-2017  Mumbai Indians  Delhi Daredevils
#
#          toss_winner toss_decision  result  dl_applied          winner  \
# 43  Delhi Daredevils         field  normal           0  Mumbai Indians
#
#     win_by_runs  win_by_wickets player_of_match             venue  \
# 43          146               0     LMP Simmons  Feroz Shah Kotla
#
#         umpire1    umpire2 umpire3
# 43  Nitin Menon  CK Nandan     NaN

# %%
ipl[ipl['win_by_runs']==10]['winner'].value_counts()
# Out:
# winner
# Rajasthan Royals               3
# Royal Challengers Bangalore    2
# Delhi Daredevils               2
# Deccan Chargers                2
# Kolkata Knight Riders          1
# Chennai Super Kings            1
# Name: count, dtype: int64

# %%
ipl[ipl['result'] == 'tie']
# Out:
#         id  season       city        date                        team1  \
# 33      34    2017     Rajkot  29-04-2017                Gujarat Lions
# 125    126    2009  Cape Town  23-04-2009             Rajasthan Royals
# 189    190    2010    Chennai  21-03-2010              Kings XI Punjab
# 387    388    2013  Hyderabad  07-04-2013  Royal Challengers Bangalore
# 400    401    2013  Bangalore  16-04-2013             Delhi Daredevils
# 475    476    2014  Abu Dhabi  29-04-2014             Rajasthan Royals
# 535    536    2015  Ahmedabad  21-04-2015             Rajasthan Royals
# 705  11146    2019      Delhi  30-03-2019        Kolkata Knight Riders
# 746  11342    2019     Mumbai  02-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 33                Mumbai Indians                Gujarat Lions           bat
# 125        Kolkata Knight Riders        Kolkata Knight Riders         field
# ...

# %%
if (ipl["win_by_wickets"] == 1).any():
    print(ipl.loc[ipl["win_by_wickets"] == 1,"result"]) 
    print(ipl["win_by_wickets"] == 1) 
else:
    print("No rows updated. No matches where wickets = 1 found.")
ipl
# Out:
# 559    normal
# 636    normal
# 642    normal
# Name: result, dtype: object
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755    False
# Name: win_by_wickets, Length: 756, dtype: bool
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2    2017           Pune  06-04-2017               Mumbai Indians
# 2        3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412    2019        Chennai  07-05-2019          Chennai Super Kings
# ...

# %%
ipl.groupby(['umpire1', 'umpire2']).size().sort_values(ascending=False)
# Out:
# umpire1               umpire2
# S Ravi                RJ Tucker        12
# Asad Rauf             S Asnani         11
# HDPK Dharmasena       CK Nandan        10
# S Ravi                C Shamshuddin     9
# RK Illingworth        VA Kulkarni       8
#                                        ..
# JD Cloete             S Ravi            1
# K Ananthapadmanabhan  Nitin Menon       1
#                       Rod Tucker        1
# K Bharatan            BNJ Oxenford      1
# Yeshwant Barde        S Ravi            1
# Length: 343, dtype: int64

# %%
ipl[ipl['dl_applied'] == 1][['season', 'toss_decision','team1','team2','toss_winner','dl_applied']]
# Out:
#      season toss_decision                        team1  \
# 56     2017         field          Sunrisers Hyderabad
# 99     2008           bat             Delhi Daredevils
# 102    2008           bat        Kolkata Knight Riders
# 119    2009         field              Kings XI Punjab
# 122    2009         field              Kings XI Punjab
# 148    2009           bat          Chennai Super Kings
# 251    2011         field          Chennai Super Kings
# 280    2011           bat          Chennai Super Kings
# 290    2011         field        Kolkata Knight Riders
# 488    2014         field             Delhi Daredevils
# 536    2015         field          Sunrisers Hyderabad
# 567    2015           bat          Sunrisers Hyderabad
# 597    2016         field          Sunrisers Hyderabad
# 620    2016           bat      Rising Pune Supergiants
# 624    2016         field             Delhi Daredevils
# 625    2016         field  Royal Challengers Bangalore
# ...

# %%
ipl.groupby(['season','winner']).size()
# Out:
# season  winner
# 2008    Chennai Super Kings             9
#         Deccan Chargers                 2
#         Delhi Daredevils                7
#         Kings XI Punjab                10
#         Kolkata Knight Riders           6
#                                        ..
# 2019    Kolkata Knight Riders           6
#         Mumbai Indians                 11
#         Rajasthan Royals                5
#         Royal Challengers Bangalore     5
#         Sunrisers Hyderabad             6
# Length: 100, dtype: int64

# %%
runs=ipl['win_by_runs'].to_numpy()
runs
# Out:
# array([ 35,   0,   0,   0,  15,   0,   0,   0,  97,   0,   0,   0,   0,
#         17,  51,   0,  27,   0,   5,  21,  15,   0,   0,  14,   0,  26,
#         82,   3,   0,   0,   0,  26,  61,   0,   0,  48,   0,   0,   0,
#          0,   0,  19,  12, 146,   0,   0,   0,  14,   0,   7,   7,   0,
#          9,   0,  10,  20,   0,   0,   1, 140,  33,   0,   0,   0,   0,
#          0,   6,   0,  66,   0,   0,   0,   0,  13,   0,  10,   0,  45,
#          0,   0,   9,  29,   0,   0,   0,   0,   0,   5,   0,   0,  18,
#         23,   0,   0,  23,   0,  41,  12,   0,   6,  65,  25,   3,   0,
#          0,   1,  14,   0,   0,  10,   3,   0,   0,   0, 105,   0,   0,
#         19,  75,   0,   0,  92,  11,  24,   9,   0,   0,  12,   0,  27,
#          0,  92,   0,   0,   3,   0,  38,   9,   8,   0,  18,   0,   0,
#         78,  78,   0,  19,   0,  12,   0,   0,   0,  16,   0,  53,   0,
#          0,  12,   0,   2,   0,   0,   0,   1,  14,   0,   0,   0,  24,
# ...

# %%
ipl['win_by_wickets'].median()
# Out:
# 4.0

# %%
ipl['win_by_runs'].max(), ipl['win_by_runs'].min()
# Out:
# (146, 0)

# %%
ipl[ipl['win_by_wickets'] == 2]
# Out:
#         id  season           city        date                    team1  \
# 48      49    2017         Kanpur  10-05-2017            Gujarat Lions
# 158    159    2009         Durban  14-05-2009      Chennai Super Kings
# 354    355    2012         Mumbai  06-05-2012      Chennai Super Kings
# 595    596    2016           Pune  24-04-2016  Rising Pune Supergiants
# 692   7950    2018         Mumbai  22-05-2018      Sunrisers Hyderabad
# 753  11413    2019  Visakhapatnam  08-05-2019      Sunrisers Hyderabad
#
#                            team2            toss_winner toss_decision  result  \
# 48              Delhi Daredevils       Delhi Daredevils         field  normal
# 158  Royal Challengers Bangalore    Chennai Super Kings           bat  normal
# 354               Mumbai Indians         Mumbai Indians         field  normal
# 595        Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 692          Chennai Super Kings    Chennai Super Kings         field  normal
# ...

# %%
ipl['win_by_runs'].std()
# Out:
# 23.471143993666452

# %%
ipl[ipl['win_by_wickets'] == 2].shape[0]
# Out:
# 6

# %%
m=ipl['winner'].str.contains('dl_applied',na=True)
ipl.loc[m,'winner']
# Out:
# 300    NaN
# 545    NaN
# 570    NaN
# 744    NaN
# Name: winner, dtype: object

# %%
ipl['toss_decision'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Toss Decisions')
plt.show()

# %%
team_wins=ipl['winner'].value_counts()
plt.bar(team_wins.index,team_wins.values,color='blue')
plt.title('Number of wins by each ipl team')
plt.xlabel('Teams')
plt.ylabel('Number of wins')
plt.xticts(rotation=80)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[129], line 6
#       4 plt.xlabel('Teams')
#       5 plt.ylabel('Number of wins')
# ----> 6 plt.xticts(rotation=80)
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xticts'
